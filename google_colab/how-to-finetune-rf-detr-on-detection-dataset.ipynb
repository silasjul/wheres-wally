# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rfdetr/pareto.png)
#
# The RF-DETR family of models stands as the quickest and most precise in object detection across all sizes. RF-DETR has achieved over 60 mAP on the Microsoft COCO benchmark, a leading measure of object detection performance. It also sets new records on RF100-VL, a benchmark that shows how well models adapt to real-world problems beyond standard datasets.
#
# The RF-DETR model group includes five sizes: Nano, Small, Medium, Base, and Large. These models offer a range of options for different needs. For example, RF-DETR-Nano is 11 mAP higher than YOLO11-n (on mAP50:95) and runs 0.17 ms faster. Likewise, RF-DETR-Small is 1.8 mAP better than YOLO11-x (the biggest YOLO11 model) and speeds things up by a good 7.77 ms. This wide range of models makes RF-DETR a great choice for many real-world uses, from small devices that need to be super fast to bigger jobs that demand top precision.
#
# RF-DETR is small enough to run on edge devices, making it perfect for deployments that need both high accuracy and real-time performance. You can easily get started with any of the RF-DETR models, as they're ready for training in the cloud with Roboflow or through the free RF-DETR Python package.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API Key
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy` to copy your private API key.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store your Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue Dec 23 12:14:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   75C    P0             35W /   72W |    1185MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies
#
# Installs RF-DETR version 1.2.1 or higher (which includes the new Nano, Small, and Medium checkpoints), along with Supervision for benchmarking and Roboflow for pulling datasets and uploading models to the Roboflow platform.

# %%
# !pip install -q rfdetr==1.2.1 supervision==0.26.1 roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 16.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.2/207.2 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 76.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 112.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 84.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.8/372.8 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 81.7 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Download example data
#
# Downloads example images for testing. You can use these or replace them with your own images.

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model
#
# Runs inference on an example image using a pretrained RF-DETR Medium model (trained on COCO). To use a different model size, simply replace `RFDETRMedium` with `RFDETRNano`, `RFDETRSmall`, `RFDETRBase` or `RFDETRLarge` as needed.

# %%
import numpy as np
import supervision as sv

from PIL import Image

from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES

image = Image.open("dog-2.jpeg")

model = RFDETRMedium(resolution=640)
model.optimize_for_inference()

detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image.thumbnail((800, 800))
annotated_image
# Out:
# UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
# rf-detr-medium.pth: 100%|██████████| 386M/386M [00:18<00:00, 22.4MiB/s]
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
# <PIL.Image.Image image mode=RGB size=450x800>

# %% [markdown]
# ## Download Dataset from Roboflow Universe
#
# RF-DETR expects the dataset to be in COCO format. Divide your dataset into three subdirectories: `train`, `valid`, and `test`. Each subdirectory should contain its own `_annotations.coco.json` file that holds the annotations for that particular split, along with the corresponding image files. Below is an example of the directory structure:
#
# ```
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)
# ```
#
# [Roboflow](https://roboflow.com/annotate) allows you to create object detection datasets from scratch or convert existing datasets from formats like YOLO, and then export them in COCO JSON format for training. You can also explore [Roboflow Universe](https://universe.roboflow.com/) to find pre-labeled datasets for a range of use cases.

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.

# %%
from rfdetr import RFDETRMedium

model = RFDETRMedium()

model.train(dataset_dir="drive/MyDrive/wheres-wally", epochs=10, batch_size=8, grad_accum_steps=2, output_dir="drive/MyDrive/wheres-wally", early_stopping=True)
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 5 classes
# reinitializing your detection head with 5 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir drive/MyDrive/wheres-wally' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=5, grad_accum_steps=2, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=8, weight_decay=0.0001, epochs=10, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-medium.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=4, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='drive/MyDrive/wheres-wally', square_resize_div_64=True, output_dir='drive/MyDrive/wheres-wally', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=576, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=36, tensorboard=True, wandb=False, project=None, run=None, class_names=['odwald', 'wally', 'wenda', 'wizard_whitebeard'], run_test=True, distributed=False)
# number of params: 33378030
# [736]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [736]
# loading annotations into memory...
# Done (t=0.90s)
# creating index...
# index created!
# [736]
# loading annotations into memory...
# Done (t=1.19s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 35
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
# UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:345.)
# Epoch: [0]  [ 0/35]  eta: 0:11:25  lr: 0.000100  class_error: 83.76  loss: 12.8276 (12.8276)  loss_ce: 0.7763 (0.7763)  loss_bbox: 0.4799 (0.4799)  loss_giou: 1.1875 (1.1875)  loss_ce_0: 0.6711 (0.6711)  loss_bbox_0: 0.6188 (0.6188)  loss_giou_0: 1.3760 (1.3760)  loss_ce_1: 0.7198 (0.7198)  loss_bbox_1: 0.5391 (0.5391)  loss_giou_1: 1.2788 (1.2788)  loss_ce_2: 0.7553 (0.7553)  loss_bbox_2: 0.5168 (0.5168)  loss_giou_2: 1.2166 (1.2166)  loss_ce_enc: 0.6636 (0.6636)  loss_bbox_enc: 0.6210 (0.6210)  loss_giou_enc: 1.4069 (1.4069)  loss_ce_unscaled: 0.7763 (0.7763)  class_error_unscaled: 83.7607 (83.7607)  loss_bbox_unscaled: 0.0960 (0.0960)  loss_giou_unscaled: 0.5937 (0.5937)  cardinality_error_unscaled: 3116.8750 (3116.8750)  loss_ce_0_unscaled: 0.6711 (0.6711)  loss_bbox_0_unscaled: 0.1238 (0.1238)  loss_giou_0_unscaled: 0.6880 (0.6880)  cardinality_error_0_unscaled: 1958.8750 (1958.8750)  loss_ce_1_unscaled: 0.7198 (0.7198)  loss_bbox_1_unscaled: 0.1078 (0.1078)  loss_giou_1_unscaled: 0.6394 (0.6394)  cardinality_error_1_unscaled: 1988.1250 (1988.1250)  loss_ce_2_unscaled: 0.7553 (0.7553)  loss_bbox_2_unscaled: 0.1034 (0.1034)  loss_giou_2_unscaled: 0.6083 (0.6083)  cardinality_error_2_unscaled: 2378.2500 (2378.2500)  loss_ce_enc_unscaled: 0.6636 (0.6636)  loss_bbox_enc_unscaled: 0.1242 (0.1242)  loss_giou_enc_unscaled: 0.7035 (0.7035)  cardinality_error_enc_unscaled: 3219.8750 (3219.8750)  time: 19.5889  data: 17.1849  max mem: 6539
# Epoch: [0]  [10/35]  eta: 0:03:35  lr: 0.000100  class_error: 78.85  loss: 12.1416 (12.1778)  loss_ce: 0.8682 (0.8470)  loss_bbox: 0.3793 (0.3814)  loss_giou: 1.0501 (1.0909)  loss_ce_0: 0.7646 (0.7488)  loss_bbox_0: 0.4826 (0.4826)  loss_giou_0: 1.2727 (1.2798)  loss_ce_1: 0.8016 (0.7980)  loss_bbox_1: 0.4388 (0.4472)  loss_giou_1: 1.1866 (1.1827)  loss_ce_2: 0.8510 (0.8257)  loss_bbox_2: 0.4023 (0.4058)  loss_giou_2: 1.1044 (1.1317)  loss_ce_enc: 0.7142 (0.7190)  loss_bbox_enc: 0.5213 (0.5081)  loss_giou_enc: 1.3455 (1.3293)  loss_ce_unscaled: 0.8682 (0.8470)  class_error_unscaled: 79.4872 (78.8950)  loss_bbox_unscaled: 0.0759 (0.0763)  loss_giou_unscaled: 0.5250 (0.5455)  cardinality_error_unscaled: 3116.8750 (3080.4773)  loss_ce_0_unscaled: 0.7646 (0.7488)  loss_bbox_0_unscaled: 0.0965 (0.0965)  loss_giou_0_unscaled: 0.6364 (0.6399)  cardinality_error_0_unscaled: 2236.5000 (2213.5114)  loss_ce_1_unscaled: 0.8016 (0.7980)  loss_bbox_1_unscaled: 0.0878 (0.0894)  loss_giou_1_unscaled: 0.5933 (0.5913)  cardinality_error_1_unscaled: 2203.7500 (2157.3636)  loss_ce_2_unscaled: 0.8510 (0.8257)  loss_bbox_2_unscaled: 0.0805 (0.0812)  loss_giou_2_unscaled: 0.5522 (0.5658)  cardinality_error_2_unscaled: 2496.1250 (2492.2614)  loss_ce_enc_unscaled: 0.7142 (0.7190)  loss_bbox_enc_unscaled: 0.1043 (0.1016)  loss_giou_enc_unscaled: 0.6727 (0.6647)  cardinality_error_enc_unscaled: 3188.2500 (3185.1705)  time: 8.6101  data: 7.5936  max mem: 7943
# Epoch: [0]  [20/35]  eta: 0:02:07  lr: 0.000100  class_error: 58.04  loss: 11.5137 (11.6732)  loss_ce: 0.8961 (0.9153)  loss_bbox: 0.3233 (0.3276)  loss_giou: 1.0074 (0.9791)  loss_ce_0: 0.7916 (0.8113)  loss_bbox_0: 0.3704 (0.4198)  loss_giou_0: 1.2105 (1.1684)  loss_ce_1: 0.8502 (0.8624)  loss_bbox_1: 0.3853 (0.3872)  loss_giou_1: 1.0967 (1.0730)  loss_ce_2: 0.8731 (0.8915)  loss_bbox_2: 0.3383 (0.3480)  loss_giou_2: 1.0483 (1.0194)  loss_ce_enc: 0.7518 (0.7654)  loss_bbox_enc: 0.4058 (0.4576)  loss_giou_enc: 1.2399 (1.2472)  loss_ce_unscaled: 0.8961 (0.9153)  class_error_unscaled: 77.6224 (78.0131)  loss_bbox_unscaled: 0.0647 (0.0655)  loss_giou_unscaled: 0.5037 (0.4895)  cardinality_error_unscaled: 3102.0000 (3075.3155)  loss_ce_0_unscaled: 0.7916 (0.8113)  loss_bbox_0_unscaled: 0.0741 (0.0840)  loss_giou_0_unscaled: 0.6052 (0.5842)  cardinality_error_0_unscaled: 2304.8750 (2307.0119)  loss_ce_1_unscaled: 0.8502 (0.8624)  loss_bbox_1_unscaled: 0.0771 (0.0774)  loss_giou_1_unscaled: 0.5483 (0.5365)  cardinality_error_1_unscaled: 2386.1250 (2366.0298)  loss_ce_2_unscaled: 0.8731 (0.8915)  loss_bbox_2_unscaled: 0.0677 (0.0696)  loss_giou_2_unscaled: 0.5241 (0.5097)  cardinality_error_2_unscaled: 2522.2500 (2535.2440)  loss_ce_enc_unscaled: 0.7518 (0.7654)  loss_bbox_enc_unscaled: 0.0812 (0.0915)  loss_giou_enc_unscaled: 0.6199 (0.6236)  cardinality_error_enc_unscaled: 3176.5000 (3172.4048)  time: 7.9318  data: 7.0369  max mem: 8355
# Epoch: [0]  [30/35]  eta: 0:00:41  lr: 0.000100  class_error: 68.27  loss: 10.4481 (11.2115)  loss_ce: 1.0737 (0.9807)  loss_bbox: 0.2146 (0.2826)  loss_giou: 0.7103 (0.8741)  loss_ce_0: 0.9676 (0.8767)  loss_bbox_0: 0.2876 (0.3671)  loss_giou_0: 0.8834 (1.0534)  loss_ce_1: 1.0183 (0.9276)  loss_bbox_1: 0.2569 (0.3349)  loss_giou_1: 0.8087 (0.9639)  loss_ce_2: 1.0507 (0.9574)  loss_bbox_2: 0.2278 (0.2993)  loss_giou_2: 0.7547 (0.9115)  loss_ce_enc: 0.8746 (0.8201)  loss_bbox_enc: 0.3472 (0.4104)  loss_giou_enc: 1.0332 (1.1518)  loss_ce_unscaled: 1.0737 (0.9807)  class_error_unscaled: 74.6154 (77.5221)  loss_bbox_unscaled: 0.0429 (0.0565)  loss_giou_unscaled: 0.3551 (0.4370)  cardinality_error_unscaled: 3089.3750 (3075.9637)  loss_ce_0_unscaled: 0.9676 (0.8767)  loss_bbox_0_unscaled: 0.0575 (0.0734)  loss_giou_0_unscaled: 0.4417 (0.5267)  cardinality_error_0_unscaled: 2571.8750 (2414.7177)  loss_ce_1_unscaled: 1.0183 (0.9276)  loss_bbox_1_unscaled: 0.0514 (0.0670)  loss_giou_1_unscaled: 0.4043 (0.4820)  cardinality_error_1_unscaled: 2759.0000 (2505.3105)  loss_ce_2_unscaled: 1.0507 (0.9574)  loss_bbox_2_unscaled: 0.0456 (0.0599)  loss_giou_2_unscaled: 0.3773 (0.4558)  cardinality_error_2_unscaled: 2747.8750 (2638.6653)  loss_ce_enc_unscaled: 0.8746 (0.8201)  loss_bbox_enc_unscaled: 0.0694 (0.0821)  loss_giou_enc_unscaled: 0.5166 (0.5759)  cardinality_error_enc_unscaled: 3123.1250 (3133.4839)  time: 8.2320  data: 7.3331  max mem: 8355
# Epoch: [0]  [34/35]  eta: 0:00:08  lr: 0.000100  class_error: 62.18  loss: 10.3571 (11.0765)  loss_ce: 1.1058 (1.0002)  loss_bbox: 0.1906 (0.2698)  loss_giou: 0.6614 (0.8442)  loss_ce_0: 0.9833 (0.8963)  loss_bbox_0: 0.2707 (0.3510)  loss_giou_0: 0.8298 (1.0205)  loss_ce_1: 1.0400 (0.9464)  loss_bbox_1: 0.2365 (0.3192)  loss_giou_1: 0.7490 (0.9339)  loss_ce_2: 1.0924 (0.9785)  loss_bbox_2: 0.2013 (0.2849)  loss_giou_2: 0.6803 (0.8783)  loss_ce_enc: 0.9154 (0.8374)  loss_bbox_enc: 0.3298 (0.3937)  loss_giou_enc: 0.9770 (1.1221)  loss_ce_unscaled: 1.1058 (1.0002)  class_error_unscaled: 71.5976 (76.1815)  loss_bbox_unscaled: 0.0381 (0.0540)  loss_giou_unscaled: 0.3307 (0.4221)  cardinality_error_unscaled: 3085.7500 (3061.8571)  loss_ce_0_unscaled: 0.9833 (0.8963)  loss_bbox_0_unscaled: 0.0541 (0.0702)  loss_giou_0_unscaled: 0.4149 (0.5103)  cardinality_error_0_unscaled: 2625.5000 (2429.3071)  loss_ce_1_unscaled: 1.0400 (0.9464)  loss_bbox_1_unscaled: 0.0473 (0.0638)  loss_giou_1_unscaled: 0.3745 (0.4669)  cardinality_error_1_unscaled: 2759.0000 (2517.3214)  loss_ce_2_unscaled: 1.0924 (0.9785)  loss_bbox_2_unscaled: 0.0403 (0.0570)  loss_giou_2_unscaled: 0.3401 (0.4392)  cardinality_error_2_unscaled: 2811.7500 (2659.7929)  loss_ce_enc_unscaled: 0.9154 (0.8374)  loss_bbox_enc_unscaled: 0.0660 (0.0787)  loss_giou_enc_unscaled: 0.4885 (0.5610)  cardinality_error_enc_unscaled: 3084.0000 (3116.6536)  time: 8.0589  data: 7.1594  max mem: 8355
# Epoch: [0] Total time: 0:04:49 (8.2847 s / it)
# Averaged stats: lr: 0.000100  class_error: 62.18  loss: 10.3571 (11.0765)  loss_ce: 1.1058 (1.0002)  loss_bbox: 0.1906 (0.2698)  loss_giou: 0.6614 (0.8442)  loss_ce_0: 0.9833 (0.8963)  loss_bbox_0: 0.2707 (0.3510)  loss_giou_0: 0.8298 (1.0205)  loss_ce_1: 1.0400 (0.9464)  loss_bbox_1: 0.2365 (0.3192)  loss_giou_1: 0.7490 (0.9339)  loss_ce_2: 1.0924 (0.9785)  loss_bbox_2: 0.2013 (0.2849)  loss_giou_2: 0.6803 (0.8783)  loss_ce_enc: 0.9154 (0.8374)  loss_bbox_enc: 0.3298 (0.3937)  loss_giou_enc: 0.9770 (1.1221)  loss_ce_unscaled: 1.1058 (1.0002)  class_error_unscaled: 71.5976 (76.1815)  loss_bbox_unscaled: 0.0381 (0.0540)  loss_giou_unscaled: 0.3307 (0.4221)  cardinality_error_unscaled: 3085.7500 (3061.8571)  loss_ce_0_unscaled: 0.9833 (0.8963)  loss_bbox_0_unscaled: 0.0541 (0.0702)  loss_giou_0_unscaled: 0.4149 (0.5103)  cardinality_error_0_unscaled: 2625.5000 (2429.3071)  loss_ce_1_unscaled: 1.0400 (0.9464)  loss_bbox_1_unscaled: 0.0473 (0.0638)  loss_giou_1_unscaled: 0.3745 (0.4669)  cardinality_error_1_unscaled: 2759.0000 (2517.3214)  loss_ce_2_unscaled: 1.0924 (0.9785)  loss_bbox_2_unscaled: 0.0403 (0.0570)  loss_giou_2_unscaled: 0.3401 (0.4392)  cardinality_error_2_unscaled: 2811.7500 (2659.7929)  loss_ce_enc_unscaled: 0.9154 (0.8374)  loss_bbox_enc_unscaled: 0.0660 (0.0787)  loss_giou_enc_unscaled: 0.4885 (0.5610)  cardinality_error_enc_unscaled: 3084.0000 (3116.6536)
# Test:  [0/2]  eta: 0:00:16  class_error: 70.00  loss: 10.0959 (10.0959)  loss_ce: 1.1641 (1.1641)  loss_bbox: 0.1892 (0.1892)  loss_giou: 0.6188 (0.6188)  loss_ce_0: 1.1094 (1.1094)  loss_bbox_0: 0.2338 (0.2338)  loss_giou_0: 0.7073 (0.7073)  loss_ce_1: 1.1172 (1.1172)  loss_bbox_1: 0.2226 (0.2226)  loss_giou_1: 0.6760 (0.6760)  loss_ce_2: 1.1328 (1.1328)  loss_bbox_2: 0.2094 (0.2094)  loss_giou_2: 0.6626 (0.6626)  loss_ce_enc: 1.0469 (1.0469)  loss_bbox_enc: 0.2371 (0.2371)  loss_giou_enc: 0.7688 (0.7688)  loss_ce_unscaled: 1.1641 (1.1641)  class_error_unscaled: 70.0000 (70.0000)  loss_bbox_unscaled: 0.0378 (0.0378)  loss_giou_unscaled: 0.3094 (0.3094)  cardinality_error_unscaled: 252.2500 (252.2500)  loss_ce_0_unscaled: 1.1094 (1.1094)  loss_bbox_0_unscaled: 0.0468 (0.0468)  loss_giou_0_unscaled: 0.3537 (0.3537)  cardinality_error_0_unscaled: 160.5000 (160.5000)  loss_ce_1_unscaled: 1.1172 (1.1172)  loss_bbox_1_unscaled: 0.0445 (0.0445)  loss_giou_1_unscaled: 0.3380 (0.3380)  cardinality_error_1_unscaled: 207.7500 (207.7500)  loss_ce_2_unscaled: 1.1328 (1.1328)  loss_bbox_2_unscaled: 0.0419 (0.0419)  loss_giou_2_unscaled: 0.3313 (0.3313)  cardinality_error_2_unscaled: 232.6250 (232.6250)  loss_ce_enc_unscaled: 1.0469 (1.0469)  loss_bbox_enc_unscaled: 0.0474 (0.0474)  loss_giou_enc_unscaled: 0.3844 (0.3844)  cardinality_error_enc_unscaled: 223.0000 (223.0000)  time: 8.0109  data: 7.8742  max mem: 8355
# Test:  [1/2]  eta: 0:00:04  class_error: 80.00  loss: 10.0959 (11.2894)  loss_ce: 0.9375 (1.0508)  loss_bbox: 0.1892 (0.2668)  loss_giou: 0.6188 (0.8300)  loss_ce_0: 0.6797 (0.8945)  loss_bbox_0: 0.2338 (0.3666)  loss_giou_0: 0.7073 (1.0660)  loss_ce_1: 0.8555 (0.9863)  loss_bbox_1: 0.2226 (0.3086)  loss_giou_1: 0.6760 (0.9216)  loss_ce_2: 0.8672 (1.0000)  loss_bbox_2: 0.2094 (0.2917)  loss_giou_2: 0.6626 (0.9089)  loss_ce_enc: 0.6094 (0.8281)  loss_bbox_enc: 0.2371 (0.3911)  loss_giou_enc: 0.7688 (1.1784)  loss_ce_unscaled: 0.9375 (1.0508)  class_error_unscaled: 70.0000 (75.0000)  loss_bbox_unscaled: 0.0378 (0.0534)  loss_giou_unscaled: 0.3094 (0.4150)  cardinality_error_unscaled: 244.2000 (248.2250)  loss_ce_0_unscaled: 0.6797 (0.8945)  loss_bbox_0_unscaled: 0.0468 (0.0733)  loss_giou_0_unscaled: 0.3537 (0.5330)  cardinality_error_0_unscaled: 160.5000 (168.1500)  loss_ce_1_unscaled: 0.8555 (0.9863)  loss_bbox_1_unscaled: 0.0445 (0.0617)  loss_giou_1_unscaled: 0.3380 (0.4608)  cardinality_error_1_unscaled: 203.2000 (205.4750)  loss_ce_2_unscaled: 0.8672 (1.0000)  loss_bbox_2_unscaled: 0.0419 (0.0583)  loss_giou_2_unscaled: 0.3313 (0.4544)  cardinality_error_2_unscaled: 223.8000 (228.2125)  loss_ce_enc_unscaled: 0.6094 (0.8281)  loss_bbox_enc_unscaled: 0.0474 (0.0782)  loss_giou_enc_unscaled: 0.3844 (0.5892)  cardinality_error_enc_unscaled: 149.6000 (186.3000)  time: 4.0571  data: 3.9401  max mem: 8355
# Test: Total time: 0:00:08 (4.0805 s / it)
# Averaged stats: class_error: 80.00  loss: 10.0959 (11.2894)  loss_ce: 0.9375 (1.0508)  loss_bbox: 0.1892 (0.2668)  loss_giou: 0.6188 (0.8300)  loss_ce_0: 0.6797 (0.8945)  loss_bbox_0: 0.2338 (0.3666)  loss_giou_0: 0.7073 (1.0660)  loss_ce_1: 0.8555 (0.9863)  loss_bbox_1: 0.2226 (0.3086)  loss_giou_1: 0.6760 (0.9216)  loss_ce_2: 0.8672 (1.0000)  loss_bbox_2: 0.2094 (0.2917)  loss_giou_2: 0.6626 (0.9089)  loss_ce_enc: 0.6094 (0.8281)  loss_bbox_enc: 0.2371 (0.3911)  loss_giou_enc: 0.7688 (1.1784)  loss_ce_unscaled: 0.9375 (1.0508)  class_error_unscaled: 70.0000 (75.0000)  loss_bbox_unscaled: 0.0378 (0.0534)  loss_giou_unscaled: 0.3094 (0.4150)  cardinality_error_unscaled: 244.2000 (248.2250)  loss_ce_0_unscaled: 0.6797 (0.8945)  loss_bbox_0_unscaled: 0.0468 (0.0733)  loss_giou_0_unscaled: 0.3537 (0.5330)  cardinality_error_0_unscaled: 160.5000 (168.1500)  loss_ce_1_unscaled: 0.8555 (0.9863)  loss_bbox_1_unscaled: 0.0445 (0.0617)  loss_giou_1_unscaled: 0.3380 (0.4608)  cardinality_error_1_unscaled: 203.2000 (205.4750)  loss_ce_2_unscaled: 0.8672 (1.0000)  loss_bbox_2_unscaled: 0.0419 (0.0583)  loss_giou_2_unscaled: 0.3313 (0.4544)  cardinality_error_2_unscaled: 223.8000 (228.2125)  loss_ce_enc_unscaled: 0.6094 (0.8281)  loss_bbox_enc_unscaled: 0.0474 (0.0782)  loss_giou_enc_unscaled: 0.3844 (0.5892)  cardinality_error_enc_unscaled: 149.6000 (186.3000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# RuntimeWarning: invalid value encountered in divide
# Test:  [0/2]  eta: 0:00:01  class_error: 60.00  loss: 9.9065 (9.9065)  loss_ce: 1.1641 (1.1641)  loss_bbox: 0.2228 (0.2228)  loss_giou: 0.5886 (0.5886)  loss_ce_0: 1.1406 (1.1406)  loss_bbox_0: 0.2075 (0.2075)  loss_giou_0: 0.5843 (0.5843)  loss_ce_1: 1.1484 (1.1484)  loss_bbox_1: 0.2727 (0.2727)  loss_giou_1: 0.5792 (0.5792)  loss_ce_2: 1.1562 (1.1562)  loss_bbox_2: 0.2511 (0.2511)  loss_giou_2: 0.5756 (0.5756)  loss_ce_enc: 1.0781 (1.0781)  loss_bbox_enc: 0.2542 (0.2542)  loss_giou_enc: 0.6830 (0.6830)  loss_ce_unscaled: 1.1641 (1.1641)  class_error_unscaled: 60.0000 (60.0000)  loss_bbox_unscaled: 0.0446 (0.0446)  loss_giou_unscaled: 0.2943 (0.2943)  cardinality_error_unscaled: 253.3750 (253.3750)  loss_ce_0_unscaled: 1.1406 (1.1406)  loss_bbox_0_unscaled: 0.0415 (0.0415)  loss_giou_0_unscaled: 0.2922 (0.2922)  cardinality_error_0_unscaled: 158.1250 (158.1250)  loss_ce_1_unscaled: 1.1484 (1.1484)  loss_bbox_1_unscaled: 0.0545 (0.0545)  loss_giou_1_unscaled: 0.2896 (0.2896)  cardinality_error_1_unscaled: 207.8750 (207.8750)  loss_ce_2_unscaled: 1.1562 (1.1562)  loss_bbox_2_unscaled: 0.0502 (0.0502)  loss_giou_2_unscaled: 0.2878 (0.2878)  cardinality_error_2_unscaled: 233.7500 (233.7500)  loss_ce_enc_unscaled: 1.0781 (1.0781)  loss_bbox_enc_unscaled: 0.0508 (0.0508)  loss_giou_enc_unscaled: 0.3415 (0.3415)  cardinality_error_enc_unscaled: 222.2500 (222.2500)  time: 0.6562  data: 0.4882  max mem: 8355
# Test:  [1/2]  eta: 0:00:00  class_error: 60.00  loss: 9.9065 (11.1320)  loss_ce: 0.9062 (1.0352)  loss_bbox: 0.2228 (0.2769)  loss_giou: 0.5886 (0.8774)  loss_ce_0: 0.7500 (0.9453)  loss_bbox_0: 0.2075 (0.3359)  loss_giou_0: 0.5843 (0.9367)  loss_ce_1: 0.8750 (1.0117)  loss_bbox_1: 0.2727 (0.3399)  loss_giou_1: 0.5792 (0.8414)  loss_ce_2: 0.8555 (1.0059)  loss_bbox_2: 0.2511 (0.3305)  loss_giou_2: 0.5756 (0.8625)  loss_ce_enc: 0.6719 (0.8750)  loss_bbox_enc: 0.2542 (0.3740)  loss_giou_enc: 0.6830 (1.0837)  loss_ce_unscaled: 0.9062 (1.0352)  class_error_unscaled: 60.0000 (60.0000)  loss_bbox_unscaled: 0.0446 (0.0554)  loss_giou_unscaled: 0.2943 (0.4387)  cardinality_error_unscaled: 244.6000 (248.9875)  loss_ce_0_unscaled: 0.7500 (0.9453)  loss_bbox_0_unscaled: 0.0415 (0.0672)  loss_giou_0_unscaled: 0.2922 (0.4684)  cardinality_error_0_unscaled: 158.1250 (167.6625)  loss_ce_1_unscaled: 0.8750 (1.0117)  loss_bbox_1_unscaled: 0.0545 (0.0680)  loss_giou_1_unscaled: 0.2896 (0.4207)  cardinality_error_1_unscaled: 203.6000 (205.7375)  loss_ce_2_unscaled: 0.8555 (1.0059)  loss_bbox_2_unscaled: 0.0502 (0.0661)  loss_giou_2_unscaled: 0.2878 (0.4313)  cardinality_error_2_unscaled: 221.4000 (227.5750)  loss_ce_enc_unscaled: 0.6719 (0.8750)  loss_bbox_enc_unscaled: 0.0508 (0.0748)  loss_giou_enc_unscaled: 0.3415 (0.5419)  cardinality_error_enc_unscaled: 148.0000 (185.1250)  time: 0.3823  data: 0.2471  max mem: 8355
# Test: Total time: 0:00:00 (0.4140 s / it)
# Averaged stats: class_error: 60.00  loss: 9.9065 (11.1320)  loss_ce: 0.9062 (1.0352)  loss_bbox: 0.2228 (0.2769)  loss_giou: 0.5886 (0.8774)  loss_ce_0: 0.7500 (0.9453)  loss_bbox_0: 0.2075 (0.3359)  loss_giou_0: 0.5843 (0.9367)  loss_ce_1: 0.8750 (1.0117)  loss_bbox_1: 0.2727 (0.3399)  loss_giou_1: 0.5792 (0.8414)  loss_ce_2: 0.8555 (1.0059)  loss_bbox_2: 0.2511 (0.3305)  loss_giou_2: 0.5756 (0.8625)  loss_ce_enc: 0.6719 (0.8750)  loss_bbox_enc: 0.2542 (0.3740)  loss_giou_enc: 0.6830 (1.0837)  loss_ce_unscaled: 0.9062 (1.0352)  class_error_unscaled: 60.0000 (60.0000)  loss_bbox_unscaled: 0.0446 (0.0554)  loss_giou_unscaled: 0.2943 (0.4387)  cardinality_error_unscaled: 244.6000 (248.9875)  loss_ce_0_unscaled: 0.7500 (0.9453)  loss_bbox_0_unscaled: 0.0415 (0.0672)  loss_giou_0_unscaled: 0.2922 (0.4684)  cardinality_error_0_unscaled: 158.1250 (167.6625)  loss_ce_1_unscaled: 0.8750 (1.0117)  loss_bbox_1_unscaled: 0.0545 (0.0680)  loss_giou_1_unscaled: 0.2896 (0.4207)  cardinality_error_1_unscaled: 203.6000 (205.7375)  loss_ce_2_unscaled: 0.8555 (1.0059)  loss_bbox_2_unscaled: 0.0502 (0.0661)  loss_giou_2_unscaled: 0.2878 (0.4313)  cardinality_error_2_unscaled: 221.4000 (227.5750)  loss_ce_enc_unscaled: 0.6719 (0.8750)  loss_bbox_enc_unscaled: 0.0508 (0.0748)  loss_giou_enc_unscaled: 0.3415 (0.5419)  cardinality_error_enc_unscaled: 148.0000 (185.1250)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.271
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Early stopping: Current mAP (max(regular, EMA)): 0.0015, Best: 0.0000, Diff: 0.0015, Min delta: 0.001
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 35
# Epoch: [1]  [ 0/35]  eta: 0:01:08  lr: 0.000100  class_error: 71.54  loss: 9.7397 (9.7397)  loss_ce: 1.2014 (1.2014)  loss_bbox: 0.1315 (0.1315)  loss_giou: 0.5237 (0.5237)  loss_ce_0: 1.0885 (1.0885)  loss_bbox_0: 0.2015 (0.2015)  loss_giou_0: 0.6898 (0.6898)  loss_ce_1: 1.1507 (1.1507)  loss_bbox_1: 0.1715 (0.1715)  loss_giou_1: 0.6013 (0.6013)  loss_ce_2: 1.1848 (1.1848)  loss_bbox_2: 0.1475 (0.1475)  loss_giou_2: 0.5406 (0.5406)  loss_ce_enc: 0.9688 (0.9688)  loss_bbox_enc: 0.2489 (0.2489)  loss_giou_enc: 0.8892 (0.8892)  loss_ce_unscaled: 1.2014 (1.2014)  class_error_unscaled: 71.5385 (71.5385)  loss_bbox_unscaled: 0.0263 (0.0263)  loss_giou_unscaled: 0.2618 (0.2618)  cardinality_error_unscaled: 3044.0000 (3044.0000)  loss_ce_0_unscaled: 1.0885 (1.0885)  loss_bbox_0_unscaled: 0.0403 (0.0403)  loss_giou_0_unscaled: 0.3449 (0.3449)  cardinality_error_0_unscaled: 2595.7500 (2595.7500)  loss_ce_1_unscaled: 1.1507 (1.1507)  loss_bbox_1_unscaled: 0.0343 (0.0343)  loss_giou_1_unscaled: 0.3006 (0.3006)  cardinality_error_1_unscaled: 2486.1250 (2486.1250)  loss_ce_2_unscaled: 1.1848 (1.1848)  loss_bbox_2_unscaled: 0.0295 (0.0295)  loss_giou_2_unscaled: 0.2703 (0.2703)  cardinality_error_2_unscaled: 2808.6250 (2808.6250)  loss_ce_enc_unscaled: 0.9688 (0.9688)  loss_bbox_enc_unscaled: 0.0498 (0.0498)  loss_giou_enc_unscaled: 0.4446 (0.4446)  cardinality_error_enc_unscaled: 2831.6250 (2831.6250)  time: 1.9479  data: 1.0208  max mem: 8355
# Epoch: [1]  [10/35]  eta: 0:00:26  lr: 0.000100  class_error: 47.93  loss: 9.6212 (9.4752)  loss_ce: 1.2381 (1.2432)  loss_bbox: 0.1170 (0.1194)  loss_giou: 0.4746 (0.4621)  loss_ce_0: 1.1514 (1.1566)  loss_bbox_0: 0.1693 (0.1672)  loss_giou_0: 0.5957 (0.5829)  loss_ce_1: 1.1914 (1.1985)  loss_bbox_1: 0.1532 (0.1453)  loss_giou_1: 0.5378 (0.5224)  loss_ce_2: 1.2158 (1.2215)  loss_bbox_2: 0.1329 (0.1279)  loss_giou_2: 0.4979 (0.4832)  loss_ce_enc: 1.0215 (1.0466)  loss_bbox_enc: 0.2413 (0.2331)  loss_giou_enc: 0.8098 (0.7652)  loss_ce_unscaled: 1.2381 (1.2432)  class_error_unscaled: 61.5385 (57.6601)  loss_bbox_unscaled: 0.0234 (0.0239)  loss_giou_unscaled: 0.2373 (0.2311)  cardinality_error_unscaled: 3163.5000 (3152.3977)  loss_ce_0_unscaled: 1.1514 (1.1566)  loss_bbox_0_unscaled: 0.0339 (0.0334)  loss_giou_0_unscaled: 0.2978 (0.2915)  cardinality_error_0_unscaled: 2532.6250 (2508.1023)  loss_ce_1_unscaled: 1.1914 (1.1985)  loss_bbox_1_unscaled: 0.0306 (0.0291)  loss_giou_1_unscaled: 0.2689 (0.2612)  cardinality_error_1_unscaled: 2531.1250 (2570.5568)  loss_ce_2_unscaled: 1.2158 (1.2215)  loss_bbox_2_unscaled: 0.0266 (0.0256)  loss_giou_2_unscaled: 0.2489 (0.2416)  cardinality_error_2_unscaled: 2918.8750 (2926.0455)  loss_ce_enc_unscaled: 1.0215 (1.0466)  loss_bbox_enc_unscaled: 0.0483 (0.0466)  loss_giou_enc_unscaled: 0.4049 (0.3826)  cardinality_error_enc_unscaled: 2798.7500 (2767.0682)  time: 1.0628  data: 0.1268  max mem: 8355
# Epoch: [1]  [20/35]  eta: 0:00:15  lr: 0.000100  class_error: 34.97  loss: 9.3284 (9.3875)  loss_ce: 1.2418 (1.2601)  loss_bbox: 0.1105 (0.1165)  loss_giou: 0.4498 (0.4442)  loss_ce_0: 1.1717 (1.1810)  loss_bbox_0: 0.1612 (0.1554)  loss_giou_0: 0.5682 (0.5489)  loss_ce_1: 1.2055 (1.2176)  loss_bbox_1: 0.1334 (0.1347)  loss_giou_1: 0.4902 (0.4921)  loss_ce_2: 1.2239 (1.2333)  loss_bbox_2: 0.1138 (0.1218)  loss_giou_2: 0.4506 (0.4599)  loss_ce_enc: 1.0797 (1.0706)  loss_bbox_enc: 0.2055 (0.2212)  loss_giou_enc: 0.7009 (0.7302)  loss_ce_unscaled: 1.2418 (1.2601)  class_error_unscaled: 50.0000 (50.8023)  loss_bbox_unscaled: 0.0221 (0.0233)  loss_giou_unscaled: 0.2249 (0.2221)  cardinality_error_unscaled: 3034.5000 (2966.8512)  loss_ce_0_unscaled: 1.1717 (1.1810)  loss_bbox_0_unscaled: 0.0322 (0.0311)  loss_giou_0_unscaled: 0.2841 (0.2744)  cardinality_error_0_unscaled: 2234.1250 (2277.8750)  loss_ce_1_unscaled: 1.2055 (1.2176)  loss_bbox_1_unscaled: 0.0267 (0.0269)  loss_giou_1_unscaled: 0.2451 (0.2460)  cardinality_error_1_unscaled: 2420.8750 (2359.3690)  loss_ce_2_unscaled: 1.2239 (1.2333)  loss_bbox_2_unscaled: 0.0228 (0.0244)  loss_giou_2_unscaled: 0.2253 (0.2300)  cardinality_error_2_unscaled: 2761.5000 (2711.5655)  loss_ce_enc_unscaled: 1.0797 (1.0706)  loss_bbox_enc_unscaled: 0.0411 (0.0442)  loss_giou_enc_unscaled: 0.3504 (0.3651)  cardinality_error_enc_unscaled: 2624.6250 (2644.5655)  time: 0.9575  data: 0.0385  max mem: 8355
# Epoch: [1]  [30/35]  eta: 0:00:04  lr: 0.000100  class_error: 25.87  loss: 9.1753 (9.2904)  loss_ce: 1.2863 (1.2712)  loss_bbox: 0.0927 (0.1107)  loss_giou: 0.4003 (0.4278)  loss_ce_0: 1.2253 (1.1953)  loss_bbox_0: 0.1306 (0.1460)  loss_giou_0: 0.4703 (0.5230)  loss_ce_1: 1.2322 (1.2205)  loss_bbox_1: 0.1069 (0.1278)  loss_giou_1: 0.4228 (0.4740)  loss_ce_2: 1.2449 (1.2336)  loss_bbox_2: 0.0970 (0.1167)  loss_giou_2: 0.4036 (0.4478)  loss_ce_enc: 1.1112 (1.0913)  loss_bbox_enc: 0.1812 (0.2062)  loss_giou_enc: 0.6617 (0.6985)  loss_ce_unscaled: 1.2863 (1.2712)  class_error_unscaled: 38.4615 (46.1584)  loss_bbox_unscaled: 0.0185 (0.0221)  loss_giou_unscaled: 0.2002 (0.2139)  cardinality_error_unscaled: 2635.7500 (2816.4879)  loss_ce_0_unscaled: 1.2253 (1.1953)  loss_bbox_0_unscaled: 0.0261 (0.0292)  loss_giou_0_unscaled: 0.2351 (0.2615)  cardinality_error_0_unscaled: 2018.7500 (2239.1331)  loss_ce_1_unscaled: 1.2322 (1.2205)  loss_bbox_1_unscaled: 0.0214 (0.0256)  loss_giou_1_unscaled: 0.2114 (0.2370)  cardinality_error_1_unscaled: 2161.0000 (2294.5000)  loss_ce_2_unscaled: 1.2449 (1.2336)  loss_bbox_2_unscaled: 0.0194 (0.0233)  loss_giou_2_unscaled: 0.2018 (0.2239)  cardinality_error_2_unscaled: 2461.0000 (2618.6573)  loss_ce_enc_unscaled: 1.1112 (1.0913)  loss_bbox_enc_unscaled: 0.0362 (0.0412)  loss_giou_enc_unscaled: 0.3308 (0.3493)  cardinality_error_enc_unscaled: 2432.3750 (2578.8387)  time: 0.9387  data: 0.0372  max mem: 8355
# Epoch: [1]  [34/35]  eta: 0:00:00  lr: 0.000100  class_error: 34.62  loss: 9.0006 (9.2264)  loss_ce: 1.2820 (1.2691)  loss_bbox: 0.0904 (0.1070)  loss_giou: 0.3832 (0.4196)  loss_ce_0: 1.2265 (1.2020)  loss_bbox_0: 0.1195 (0.1399)  loss_giou_0: 0.4662 (0.5093)  loss_ce_1: 1.2322 (1.2230)  loss_bbox_1: 0.1034 (0.1230)  loss_giou_1: 0.4118 (0.4633)  loss_ce_2: 1.2449 (1.2355)  loss_bbox_2: 0.0951 (0.1127)  loss_giou_2: 0.3976 (0.4384)  loss_ce_enc: 1.1130 (1.1010)  loss_bbox_enc: 0.1759 (0.1994)  loss_giou_enc: 0.6516 (0.6830)  loss_ce_unscaled: 1.2820 (1.2691)  class_error_unscaled: 35.1648 (43.6212)  loss_bbox_unscaled: 0.0181 (0.0214)  loss_giou_unscaled: 0.1916 (0.2098)  cardinality_error_unscaled: 2453.8750 (2763.8036)  loss_ce_0_unscaled: 1.2265 (1.2020)  loss_bbox_0_unscaled: 0.0239 (0.0280)  loss_giou_0_unscaled: 0.2331 (0.2547)  cardinality_error_0_unscaled: 2018.7500 (2235.2857)  loss_ce_1_unscaled: 1.2322 (1.2230)  loss_bbox_1_unscaled: 0.0207 (0.0246)  loss_giou_1_unscaled: 0.2059 (0.2317)  cardinality_error_1_unscaled: 2024.1250 (2269.4250)  loss_ce_2_unscaled: 1.2449 (1.2355)  loss_bbox_2_unscaled: 0.0190 (0.0225)  loss_giou_2_unscaled: 0.1988 (0.2192)  cardinality_error_2_unscaled: 2325.7500 (2576.4821)  loss_ce_enc_unscaled: 1.1130 (1.1010)  loss_bbox_enc_unscaled: 0.0352 (0.0399)  loss_giou_enc_unscaled: 0.3258 (0.3415)  cardinality_error_enc_unscaled: 2401.8750 (2551.5750)  time: 0.9325  data: 0.0362  max mem: 8355
# Epoch: [1] Total time: 0:00:34 (0.9779 s / it)
# Averaged stats: lr: 0.000100  class_error: 34.62  loss: 9.0006 (9.2264)  loss_ce: 1.2820 (1.2691)  loss_bbox: 0.0904 (0.1070)  loss_giou: 0.3832 (0.4196)  loss_ce_0: 1.2265 (1.2020)  loss_bbox_0: 0.1195 (0.1399)  loss_giou_0: 0.4662 (0.5093)  loss_ce_1: 1.2322 (1.2230)  loss_bbox_1: 0.1034 (0.1230)  loss_giou_1: 0.4118 (0.4633)  loss_ce_2: 1.2449 (1.2355)  loss_bbox_2: 0.0951 (0.1127)  loss_giou_2: 0.3976 (0.4384)  loss_ce_enc: 1.1130 (1.1010)  loss_bbox_enc: 0.1759 (0.1994)  loss_giou_enc: 0.6516 (0.6830)  loss_ce_unscaled: 1.2820 (1.2691)  class_error_unscaled: 35.1648 (43.6212)  loss_bbox_unscaled: 0.0181 (0.0214)  loss_giou_unscaled: 0.1916 (0.2098)  cardinality_error_unscaled: 2453.8750 (2763.8036)  loss_ce_0_unscaled: 1.2265 (1.2020)  loss_bbox_0_unscaled: 0.0239 (0.0280)  loss_giou_0_unscaled: 0.2331 (0.2547)  cardinality_error_0_unscaled: 2018.7500 (2235.2857)  loss_ce_1_unscaled: 1.2322 (1.2230)  loss_bbox_1_unscaled: 0.0207 (0.0246)  loss_giou_1_unscaled: 0.2059 (0.2317)  cardinality_error_1_unscaled: 2024.1250 (2269.4250)  loss_ce_2_unscaled: 1.2449 (1.2355)  loss_bbox_2_unscaled: 0.0190 (0.0225)  loss_giou_2_unscaled: 0.1988 (0.2192)  cardinality_error_2_unscaled: 2325.7500 (2576.4821)  loss_ce_enc_unscaled: 1.1130 (1.1010)  loss_bbox_enc_unscaled: 0.0352 (0.0399)  loss_giou_enc_unscaled: 0.3258 (0.3415)  cardinality_error_enc_unscaled: 2401.8750 (2551.5750)
# Test:  [0/2]  eta: 0:00:01  class_error: 30.00  loss: 9.9961 (9.9961)  loss_ce: 0.9883 (0.9883)  loss_bbox: 0.2574 (0.2574)  loss_giou: 0.7566 (0.7566)  loss_ce_0: 1.1250 (1.1250)  loss_bbox_0: 0.2325 (0.2325)  loss_giou_0: 0.6256 (0.6256)  loss_ce_1: 1.0234 (1.0234)  loss_bbox_1: 0.2630 (0.2630)  loss_giou_1: 0.7071 (0.7071)  loss_ce_2: 0.9883 (0.9883)  loss_bbox_2: 0.2507 (0.2507)  loss_giou_2: 0.7313 (0.7313)  loss_ce_enc: 1.1016 (1.1016)  loss_bbox_enc: 0.2207 (0.2207)  loss_giou_enc: 0.7246 (0.7246)  loss_ce_unscaled: 0.9883 (0.9883)  class_error_unscaled: 30.0000 (30.0000)  loss_bbox_unscaled: 0.0515 (0.0515)  loss_giou_unscaled: 0.3783 (0.3783)  cardinality_error_unscaled: 212.2500 (212.2500)  loss_ce_0_unscaled: 1.1250 (1.1250)  loss_bbox_0_unscaled: 0.0465 (0.0465)  loss_giou_0_unscaled: 0.3128 (0.3128)  cardinality_error_0_unscaled: 153.6250 (153.6250)  loss_ce_1_unscaled: 1.0234 (1.0234)  loss_bbox_1_unscaled: 0.0526 (0.0526)  loss_giou_1_unscaled: 0.3536 (0.3536)  cardinality_error_1_unscaled: 174.3750 (174.3750)  loss_ce_2_unscaled: 0.9883 (0.9883)  loss_bbox_2_unscaled: 0.0501 (0.0501)  loss_giou_2_unscaled: 0.3657 (0.3657)  cardinality_error_2_unscaled: 190.5000 (190.5000)  loss_ce_enc_unscaled: 1.1016 (1.1016)  loss_bbox_enc_unscaled: 0.0441 (0.0441)  loss_giou_enc_unscaled: 0.3623 (0.3623)  cardinality_error_enc_unscaled: 56.8750 (56.8750)  time: 0.7250  data: 0.5853  max mem: 8355
# Test:  [1/2]  eta: 0:00:00  class_error: 60.00  loss: 9.7773 (9.8867)  loss_ce: 0.9883 (1.0684)  loss_bbox: 0.1869 (0.2222)  loss_giou: 0.5944 (0.6755)  loss_ce_0: 1.1250 (1.1641)  loss_bbox_0: 0.1625 (0.1975)  loss_giou_0: 0.5656 (0.5956)  loss_ce_1: 1.0234 (1.1094)  loss_bbox_1: 0.1549 (0.2090)  loss_giou_1: 0.5570 (0.6320)  loss_ce_2: 0.9883 (1.0801)  loss_bbox_2: 0.1898 (0.2202)  loss_giou_2: 0.6033 (0.6673)  loss_ce_enc: 1.0938 (1.0977)  loss_bbox_enc: 0.2207 (0.2215)  loss_giou_enc: 0.7246 (0.7263)  loss_ce_unscaled: 0.9883 (1.0684)  class_error_unscaled: 30.0000 (45.0000)  loss_bbox_unscaled: 0.0374 (0.0444)  loss_giou_unscaled: 0.2972 (0.3378)  cardinality_error_unscaled: 206.2000 (209.2250)  loss_ce_0_unscaled: 1.1250 (1.1641)  loss_bbox_0_unscaled: 0.0325 (0.0395)  loss_giou_0_unscaled: 0.2828 (0.2978)  cardinality_error_0_unscaled: 146.0000 (149.8125)  loss_ce_1_unscaled: 1.0234 (1.1094)  loss_bbox_1_unscaled: 0.0310 (0.0418)  loss_giou_1_unscaled: 0.2785 (0.3160)  cardinality_error_1_unscaled: 165.8000 (170.0875)  loss_ce_2_unscaled: 0.9883 (1.0801)  loss_bbox_2_unscaled: 0.0380 (0.0440)  loss_giou_2_unscaled: 0.3017 (0.3337)  cardinality_error_2_unscaled: 190.5000 (191.1500)  loss_ce_enc_unscaled: 1.0938 (1.0977)  loss_bbox_enc_unscaled: 0.0441 (0.0443)  loss_giou_enc_unscaled: 0.3623 (0.3632)  cardinality_error_enc_unscaled: 44.4000 (50.6375)  time: 0.4108  data: 0.2955  max mem: 8355
# Test: Total time: 0:00:00 (0.4354 s / it)
# Averaged stats: class_error: 60.00  loss: 9.7773 (9.8867)  loss_ce: 0.9883 (1.0684)  loss_bbox: 0.1869 (0.2222)  loss_giou: 0.5944 (0.6755)  loss_ce_0: 1.1250 (1.1641)  loss_bbox_0: 0.1625 (0.1975)  loss_giou_0: 0.5656 (0.5956)  loss_ce_1: 1.0234 (1.1094)  loss_bbox_1: 0.1549 (0.2090)  loss_giou_1: 0.5570 (0.6320)  loss_ce_2: 0.9883 (1.0801)  loss_bbox_2: 0.1898 (0.2202)  loss_giou_2: 0.6033 (0.6673)  loss_ce_enc: 1.0938 (1.0977)  loss_bbox_enc: 0.2207 (0.2215)  loss_giou_enc: 0.7246 (0.7263)  loss_ce_unscaled: 0.9883 (1.0684)  class_error_unscaled: 30.0000 (45.0000)  loss_bbox_unscaled: 0.0374 (0.0444)  loss_giou_unscaled: 0.2972 (0.3378)  cardinality_error_unscaled: 206.2000 (209.2250)  loss_ce_0_unscaled: 1.1250 (1.1641)  loss_bbox_0_unscaled: 0.0325 (0.0395)  loss_giou_0_unscaled: 0.2828 (0.2978)  cardinality_error_0_unscaled: 146.0000 (149.8125)  loss_ce_1_unscaled: 1.0234 (1.1094)  loss_bbox_1_unscaled: 0.0310 (0.0418)  loss_giou_1_unscaled: 0.2785 (0.3160)  cardinality_error_1_unscaled: 165.8000 (170.0875)  loss_ce_2_unscaled: 0.9883 (1.0801)  loss_bbox_2_unscaled: 0.0380 (0.0440)  loss_giou_2_unscaled: 0.3017 (0.3337)  cardinality_error_2_unscaled: 190.5000 (191.1500)  loss_ce_enc_unscaled: 1.0938 (1.0977)  loss_bbox_enc_unscaled: 0.0441 (0.0443)  loss_giou_enc_unscaled: 0.3623 (0.3632)  cardinality_error_enc_unscaled: 44.4000 (50.6375)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Test:  [0/2]  eta: 0:00:01  class_error: 30.00  loss: 10.0246 (10.0246)  loss_ce: 1.0156 (1.0156)  loss_bbox: 0.2387 (0.2387)  loss_giou: 0.7335 (0.7335)  loss_ce_0: 1.1094 (1.1094)  loss_bbox_0: 0.2490 (0.2490)  loss_giou_0: 0.6383 (0.6383)  loss_ce_1: 1.0547 (1.0547)  loss_bbox_1: 0.2540 (0.2540)  loss_giou_1: 0.6780 (0.6780)  loss_ce_2: 1.0234 (1.0234)  loss_bbox_2: 0.2315 (0.2315)  loss_giou_2: 0.7030 (0.7030)  loss_ce_enc: 1.0703 (1.0703)  loss_bbox_enc: 0.2495 (0.2495)  loss_giou_enc: 0.7757 (0.7757)  loss_ce_unscaled: 1.0156 (1.0156)  class_error_unscaled: 30.0000 (30.0000)  loss_bbox_unscaled: 0.0477 (0.0477)  loss_giou_unscaled: 0.3667 (0.3667)  cardinality_error_unscaled: 210.5000 (210.5000)  loss_ce_0_unscaled: 1.1094 (1.1094)  loss_bbox_0_unscaled: 0.0498 (0.0498)  loss_giou_0_unscaled: 0.3192 (0.3192)  cardinality_error_0_unscaled: 157.1250 (157.1250)  loss_ce_1_unscaled: 1.0547 (1.0547)  loss_bbox_1_unscaled: 0.0508 (0.0508)  loss_giou_1_unscaled: 0.3390 (0.3390)  cardinality_error_1_unscaled: 170.2500 (170.2500)  loss_ce_2_unscaled: 1.0234 (1.0234)  loss_bbox_2_unscaled: 0.0463 (0.0463)  loss_giou_2_unscaled: 0.3515 (0.3515)  cardinality_error_2_unscaled: 191.2500 (191.2500)  loss_ce_enc_unscaled: 1.0703 (1.0703)  loss_bbox_enc_unscaled: 0.0499 (0.0499)  loss_giou_enc_unscaled: 0.3878 (0.3878)  cardinality_error_enc_unscaled: 56.8750 (56.8750)  time: 0.6133  data: 0.4514  max mem: 8355
# Test:  [1/2]  eta: 0:00:00  class_error: 40.00  loss: 9.8215 (9.9230)  loss_ce: 1.0156 (1.0977)  loss_bbox: 0.1740 (0.2064)  loss_giou: 0.5561 (0.6448)  loss_ce_0: 1.1094 (1.1406)  loss_bbox_0: 0.1859 (0.2175)  loss_giou_0: 0.6059 (0.6221)  loss_ce_1: 1.0547 (1.0977)  loss_bbox_1: 0.1636 (0.2088)  loss_giou_1: 0.6162 (0.6471)  loss_ce_2: 1.0234 (1.0898)  loss_bbox_2: 0.1841 (0.2078)  loss_giou_2: 0.6190 (0.6610)  loss_ce_enc: 1.0703 (1.0703)  loss_bbox_enc: 0.2192 (0.2344)  loss_giou_enc: 0.7757 (0.7773)  loss_ce_unscaled: 1.0156 (1.0977)  class_error_unscaled: 30.0000 (35.0000)  loss_bbox_unscaled: 0.0348 (0.0413)  loss_giou_unscaled: 0.2780 (0.3224)  cardinality_error_unscaled: 202.2000 (206.3500)  loss_ce_0_unscaled: 1.1094 (1.1406)  loss_bbox_0_unscaled: 0.0372 (0.0435)  loss_giou_0_unscaled: 0.3029 (0.3110)  cardinality_error_0_unscaled: 141.8000 (149.4625)  loss_ce_1_unscaled: 1.0547 (1.0977)  loss_bbox_1_unscaled: 0.0327 (0.0418)  loss_giou_1_unscaled: 0.3081 (0.3235)  cardinality_error_1_unscaled: 153.2000 (161.7250)  loss_ce_2_unscaled: 1.0234 (1.0898)  loss_bbox_2_unscaled: 0.0368 (0.0416)  loss_giou_2_unscaled: 0.3095 (0.3305)  cardinality_error_2_unscaled: 178.0000 (184.6250)  loss_ce_enc_unscaled: 1.0703 (1.0703)  loss_bbox_enc_unscaled: 0.0438 (0.0469)  loss_giou_enc_unscaled: 0.3878 (0.3886)  cardinality_error_enc_unscaled: 44.2000 (50.5375)  time: 0.3638  data: 0.2286  max mem: 8355
# Test: Total time: 0:00:00 (0.3881 s / it)
# Averaged stats: class_error: 40.00  loss: 9.8215 (9.9230)  loss_ce: 1.0156 (1.0977)  loss_bbox: 0.1740 (0.2064)  loss_giou: 0.5561 (0.6448)  loss_ce_0: 1.1094 (1.1406)  loss_bbox_0: 0.1859 (0.2175)  loss_giou_0: 0.6059 (0.6221)  loss_ce_1: 1.0547 (1.0977)  loss_bbox_1: 0.1636 (0.2088)  loss_giou_1: 0.6162 (0.6471)  loss_ce_2: 1.0234 (1.0898)  loss_bbox_2: 0.1841 (0.2078)  loss_giou_2: 0.6190 (0.6610)  loss_ce_enc: 1.0703 (1.0703)  loss_bbox_enc: 0.2192 (0.2344)  loss_giou_enc: 0.7757 (0.7773)  loss_ce_unscaled: 1.0156 (1.0977)  class_error_unscaled: 30.0000 (35.0000)  loss_bbox_unscaled: 0.0348 (0.0413)  loss_giou_unscaled: 0.2780 (0.3224)  cardinality_error_unscaled: 202.2000 (206.3500)  loss_ce_0_unscaled: 1.1094 (1.1406)  loss_bbox_0_unscaled: 0.0372 (0.0435)  loss_giou_0_unscaled: 0.3029 (0.3110)  cardinality_error_0_unscaled: 141.8000 (149.4625)  loss_ce_1_unscaled: 1.0547 (1.0977)  loss_bbox_1_unscaled: 0.0327 (0.0418)  loss_giou_1_unscaled: 0.3081 (0.3235)  cardinality_error_1_unscaled: 153.2000 (161.7250)  loss_ce_2_unscaled: 1.0234 (1.0898)  loss_bbox_2_unscaled: 0.0368 (0.0416)  loss_giou_2_unscaled: 0.3095 (0.3305)  cardinality_error_2_unscaled: 178.0000 (184.6250)  loss_ce_enc_unscaled: 1.0703 (1.0703)  loss_bbox_enc_unscaled: 0.0438 (0.0469)  loss_giou_enc_unscaled: 0.3878 (0.3886)  cardinality_error_enc_unscaled: 44.2000 (50.5375)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.436
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.227
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Early stopping: Current mAP (max(regular, EMA)): 0.2708, Best: 0.0015, Diff: 0.2693, Min delta: 0.001
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 35
# Epoch: [2]  [ 0/35]  eta: 0:01:52  lr: 0.000100  class_error: 5.38  loss: 8.2823 (8.2823)  loss_ce: 1.1345 (1.1345)  loss_bbox: 0.0955 (0.0955)  loss_giou: 0.3616 (0.3616)  loss_ce_0: 1.2633 (1.2633)  loss_bbox_0: 0.0827 (0.0827)  loss_giou_0: 0.3397 (0.3397)  loss_ce_1: 1.1804 (1.1804)  loss_bbox_1: 0.0962 (0.0962)  loss_giou_1: 0.3682 (0.3682)  loss_ce_2: 1.1386 (1.1386)  loss_bbox_2: 0.0937 (0.0937)  loss_giou_2: 0.3652 (0.3652)  loss_ce_enc: 1.2535 (1.2535)  loss_bbox_enc: 0.1000 (0.1000)  loss_giou_enc: 0.4090 (0.4090)  loss_ce_unscaled: 1.1345 (1.1345)  class_error_unscaled: 5.3846 (5.3846)  loss_bbox_unscaled: 0.0191 (0.0191)  loss_giou_unscaled: 0.1808 (0.1808)  cardinality_error_unscaled: 2251.2500 (2251.2500)  loss_ce_0_unscaled: 1.2633 (1.2633)  loss_bbox_0_unscaled: 0.0165 (0.0165)  loss_giou_0_unscaled: 0.1699 (0.1699)  cardinality_error_0_unscaled: 2241.7500 (2241.7500)  loss_ce_1_unscaled: 1.1804 (1.1804)  loss_bbox_1_unscaled: 0.0192 (0.0192)  loss_giou_1_unscaled: 0.1841 (0.1841)  cardinality_error_1_unscaled: 2151.8750 (2151.8750)  loss_ce_2_unscaled: 1.1386 (1.1386)  loss_bbox_2_unscaled: 0.0187 (0.0187)  loss_giou_2_unscaled: 0.1826 (0.1826)  cardinality_error_2_unscaled: 2259.0000 (2259.0000)  loss_ce_enc_unscaled: 1.2535 (1.2535)  loss_bbox_enc_unscaled: 0.0200 (0.0200)  loss_giou_enc_unscaled: 0.2045 (0.2045)  cardinality_error_enc_unscaled: 2406.8750 (2406.8750)  time: 3.2059  data: 2.3675  max mem: 8355
# Epoch: [2]  [10/35]  eta: 0:00:27  lr: 0.000100  class_error: 4.95  loss: 8.2823 (8.1714)  loss_ce: 1.0041 (1.0380)  loss_bbox: 0.0840 (0.0988)  loss_giou: 0.3327 (0.3687)  loss_ce_0: 1.2301 (1.2150)  loss_bbox_0: 0.0903 (0.1051)  loss_giou_0: 0.3411 (0.3825)  loss_ce_1: 1.1300 (1.1166)  loss_bbox_1: 0.0962 (0.1032)  loss_giou_1: 0.3396 (0.3767)  loss_ce_2: 1.0306 (1.0612)  loss_bbox_2: 0.0838 (0.0984)  loss_giou_2: 0.3354 (0.3675)  loss_ce_enc: 1.2085 (1.1993)  loss_bbox_enc: 0.1272 (0.1421)  loss_giou_enc: 0.4520 (0.4984)  loss_ce_unscaled: 1.0041 (1.0380)  class_error_unscaled: 21.5385 (20.9384)  loss_bbox_unscaled: 0.0168 (0.0198)  loss_giou_unscaled: 0.1663 (0.1843)  cardinality_error_unscaled: 2251.2500 (2183.6023)  loss_ce_0_unscaled: 1.2301 (1.2150)  loss_bbox_0_unscaled: 0.0181 (0.0210)  loss_giou_0_unscaled: 0.1705 (0.1913)  cardinality_error_0_unscaled: 2393.5000 (2356.8068)  loss_ce_1_unscaled: 1.1300 (1.1166)  loss_bbox_1_unscaled: 0.0192 (0.0206)  loss_giou_1_unscaled: 0.1698 (0.1884)  cardinality_error_1_unscaled: 2200.3750 (2199.1591)  loss_ce_2_unscaled: 1.0306 (1.0612)  loss_bbox_2_unscaled: 0.0168 (0.0197)  loss_giou_2_unscaled: 0.1677 (0.1838)  cardinality_error_2_unscaled: 2205.8750 (2186.4659)  loss_ce_enc_unscaled: 1.2085 (1.1993)  loss_bbox_enc_unscaled: 0.0254 (0.0284)  loss_giou_enc_unscaled: 0.2260 (0.2492)  cardinality_error_enc_unscaled: 2330.0000 (2325.5909)  time: 1.1180  data: 0.2484  max mem: 8355
# Epoch: [2]  [20/35]  eta: 0:00:21  lr: 0.000100  class_error: 0.85  loss: 7.5126 (7.6853)  loss_ce: 0.9465 (0.9564)  loss_bbox: 0.0687 (0.0832)  loss_giou: 0.3097 (0.3314)  loss_ce_0: 1.2169 (1.2224)  loss_bbox_0: 0.0663 (0.0833)  loss_giou_0: 0.2943 (0.3275)  loss_ce_1: 1.0799 (1.0820)  loss_bbox_1: 0.0746 (0.0846)  loss_giou_1: 0.3067 (0.3342)  loss_ce_2: 0.9948 (0.9986)  loss_bbox_2: 0.0729 (0.0828)  loss_giou_2: 0.3099 (0.3324)  loss_ce_enc: 1.2418 (1.2283)  loss_bbox_enc: 0.0897 (0.1136)  loss_giou_enc: 0.3685 (0.4247)  loss_ce_unscaled: 0.9465 (0.9564)  class_error_unscaled: 12.0879 (16.0861)  loss_bbox_unscaled: 0.0137 (0.0166)  loss_giou_unscaled: 0.1548 (0.1657)  cardinality_error_unscaled: 2264.7500 (2186.7202)  loss_ce_0_unscaled: 1.2169 (1.2224)  loss_bbox_0_unscaled: 0.0133 (0.0167)  loss_giou_0_unscaled: 0.1471 (0.1638)  cardinality_error_0_unscaled: 2393.5000 (2388.7440)  loss_ce_1_unscaled: 1.0799 (1.0820)  loss_bbox_1_unscaled: 0.0149 (0.0169)  loss_giou_1_unscaled: 0.1533 (0.1671)  cardinality_error_1_unscaled: 2146.0000 (2120.9821)  loss_ce_2_unscaled: 0.9948 (0.9986)  loss_bbox_2_unscaled: 0.0146 (0.0166)  loss_giou_2_unscaled: 0.1550 (0.1662)  cardinality_error_2_unscaled: 2172.7500 (2098.3036)  loss_ce_enc_unscaled: 1.2418 (1.2283)  loss_bbox_enc_unscaled: 0.0179 (0.0227)  loss_giou_enc_unscaled: 0.1842 (0.2123)  cardinality_error_enc_unscaled: 2316.2500 (2318.0119)  time: 1.3198  data: 0.4637  max mem: 8355
# ...
# Test: Total time: 0:00:00 (0.3830 s / it)
# Averaged stats: class_error: 40.00  loss: 9.1222 (9.6604)  loss_ce: 0.7109 (0.7676)  loss_bbox: 0.2902 (0.2940)  loss_giou: 0.8119 (0.8281)  loss_ce_0: 0.7109 (0.8398)  loss_bbox_0: 0.3008 (0.3154)  loss_giou_0: 0.7868 (0.8072)  loss_ce_1: 0.6953 (0.7754)  loss_bbox_1: 0.2914 (0.3160)  loss_giou_1: 0.8269 (0.8310)  loss_ce_2: 0.7148 (0.7676)  loss_bbox_2: 0.2775 (0.3057)  loss_giou_2: 0.8067 (0.8087)  loss_ce_enc: 0.7305 (0.8652)  loss_bbox_enc: 0.2854 (0.3122)  loss_giou_enc: 0.8014 (0.8264)  loss_ce_unscaled: 0.7109 (0.7676)  class_error_unscaled: 10.0000 (25.0000)  loss_bbox_unscaled: 0.0580 (0.0588)  loss_giou_unscaled: 0.4059 (0.4140)  cardinality_error_unscaled: 208.7500 (226.2750)  loss_ce_0_unscaled: 0.7109 (0.8398)  loss_bbox_0_unscaled: 0.0602 (0.0631)  loss_giou_0_unscaled: 0.3934 (0.4036)  cardinality_error_0_unscaled: 254.8750 (261.5375)  loss_ce_1_unscaled: 0.6953 (0.7754)  loss_bbox_1_unscaled: 0.0583 (0.0632)  loss_giou_1_unscaled: 0.4134 (0.4155)  cardinality_error_1_unscaled: 163.4000 (170.0125)  loss_ce_2_unscaled: 0.7148 (0.7676)  loss_bbox_2_unscaled: 0.0555 (0.0611)  loss_giou_2_unscaled: 0.4033 (0.4044)  cardinality_error_2_unscaled: 230.3750 (232.6875)  loss_ce_enc_unscaled: 0.7305 (0.8652)  loss_bbox_enc_unscaled: 0.0571 (0.0624)  loss_giou_enc_unscaled: 0.4007 (0.4132)  cardinality_error_enc_unscaled: 262.0000 (272.3000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.273
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.621
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Test:  [0/2]  eta: 0:00:01  class_error: 10.00  loss: 7.8885 (7.8885)  loss_ce: 0.6680 (0.6680)  loss_bbox: 0.2211 (0.2211)  loss_giou: 0.6103 (0.6103)  loss_ce_0: 0.6328 (0.6328)  loss_bbox_0: 0.2750 (0.2750)  loss_giou_0: 0.7628 (0.7628)  loss_ce_1: 0.5859 (0.5859)  loss_bbox_1: 0.2407 (0.2407)  loss_giou_1: 0.7111 (0.7111)  loss_ce_2: 0.6484 (0.6484)  loss_bbox_2: 0.2201 (0.2201)  loss_giou_2: 0.6537 (0.6537)  loss_ce_enc: 0.6836 (0.6836)  loss_bbox_enc: 0.2483 (0.2483)  loss_giou_enc: 0.7266 (0.7266)  loss_ce_unscaled: 0.6680 (0.6680)  class_error_unscaled: 10.0000 (10.0000)  loss_bbox_unscaled: 0.0442 (0.0442)  loss_giou_unscaled: 0.3051 (0.3051)  cardinality_error_unscaled: 214.0000 (214.0000)  loss_ce_0_unscaled: 0.6328 (0.6328)  loss_bbox_0_unscaled: 0.0550 (0.0550)  loss_giou_0_unscaled: 0.3814 (0.3814)  cardinality_error_0_unscaled: 259.0000 (259.0000)  loss_ce_1_unscaled: 0.5859 (0.5859)  loss_bbox_1_unscaled: 0.0481 (0.0481)  loss_giou_1_unscaled: 0.3556 (0.3556)  cardinality_error_1_unscaled: 201.2500 (201.2500)  loss_ce_2_unscaled: 0.6484 (0.6484)  loss_bbox_2_unscaled: 0.0440 (0.0440)  loss_giou_2_unscaled: 0.3269 (0.3269)  cardinality_error_2_unscaled: 232.8750 (232.8750)  loss_ce_enc_unscaled: 0.6836 (0.6836)  loss_bbox_enc_unscaled: 0.0497 (0.0497)  loss_giou_enc_unscaled: 0.3633 (0.3633)  cardinality_error_enc_unscaled: 255.6250 (255.6250)  time: 0.6419  data: 0.4700  max mem: 8355
# Test:  [1/2]  eta: 0:00:00  class_error: 0.00  loss: 7.8885 (8.4787)  loss_ce: 0.6680 (0.7676)  loss_bbox: 0.2211 (0.2404)  loss_giou: 0.6103 (0.6157)  loss_ce_0: 0.6328 (0.7480)  loss_bbox_0: 0.2750 (0.2940)  loss_giou_0: 0.7628 (0.7670)  loss_ce_1: 0.5859 (0.7461)  loss_bbox_1: 0.2407 (0.2536)  loss_giou_1: 0.6391 (0.6751)  loss_ce_2: 0.6484 (0.8027)  loss_bbox_2: 0.1620 (0.1911)  loss_giou_2: 0.4931 (0.5734)  loss_ce_enc: 0.6836 (0.8301)  loss_bbox_enc: 0.2483 (0.2724)  loss_giou_enc: 0.6761 (0.7013)  loss_ce_unscaled: 0.6680 (0.7676)  class_error_unscaled: 0.0000 (5.0000)  loss_bbox_unscaled: 0.0442 (0.0481)  loss_giou_unscaled: 0.3051 (0.3079)  cardinality_error_unscaled: 214.0000 (233.3000)  loss_ce_0_unscaled: 0.6328 (0.7480)  loss_bbox_0_unscaled: 0.0550 (0.0588)  loss_giou_0_unscaled: 0.3814 (0.3835)  cardinality_error_0_unscaled: 259.0000 (267.4000)  loss_ce_1_unscaled: 0.5859 (0.7461)  loss_bbox_1_unscaled: 0.0481 (0.0507)  loss_giou_1_unscaled: 0.3196 (0.3376)  cardinality_error_1_unscaled: 201.2500 (205.5250)  loss_ce_2_unscaled: 0.6484 (0.8027)  loss_bbox_2_unscaled: 0.0324 (0.0382)  loss_giou_2_unscaled: 0.2466 (0.2867)  cardinality_error_2_unscaled: 232.8750 (237.7375)  loss_ce_enc_unscaled: 0.6836 (0.8301)  loss_bbox_enc_unscaled: 0.0497 (0.0545)  loss_giou_enc_unscaled: 0.3381 (0.3507)  cardinality_error_enc_unscaled: 255.6250 (269.9125)  time: 0.3820  data: 0.2381  max mem: 8355
# Test: Total time: 0:00:00 (0.4092 s / it)
# Averaged stats: class_error: 0.00  loss: 7.8885 (8.4787)  loss_ce: 0.6680 (0.7676)  loss_bbox: 0.2211 (0.2404)  loss_giou: 0.6103 (0.6157)  loss_ce_0: 0.6328 (0.7480)  loss_bbox_0: 0.2750 (0.2940)  loss_giou_0: 0.7628 (0.7670)  loss_ce_1: 0.5859 (0.7461)  loss_bbox_1: 0.2407 (0.2536)  loss_giou_1: 0.6391 (0.6751)  loss_ce_2: 0.6484 (0.8027)  loss_bbox_2: 0.1620 (0.1911)  loss_giou_2: 0.4931 (0.5734)  loss_ce_enc: 0.6836 (0.8301)  loss_bbox_enc: 0.2483 (0.2724)  loss_giou_enc: 0.6761 (0.7013)  loss_ce_unscaled: 0.6680 (0.7676)  class_error_unscaled: 0.0000 (5.0000)  loss_bbox_unscaled: 0.0442 (0.0481)  loss_giou_unscaled: 0.3051 (0.3079)  cardinality_error_unscaled: 214.0000 (233.3000)  loss_ce_0_unscaled: 0.6328 (0.7480)  loss_bbox_0_unscaled: 0.0550 (0.0588)  loss_giou_0_unscaled: 0.3814 (0.3835)  cardinality_error_0_unscaled: 259.0000 (267.4000)  loss_ce_1_unscaled: 0.5859 (0.7461)  loss_bbox_1_unscaled: 0.0481 (0.0507)  loss_giou_1_unscaled: 0.3196 (0.3376)  cardinality_error_1_unscaled: 201.2500 (205.5250)  loss_ce_2_unscaled: 0.6484 (0.8027)  loss_bbox_2_unscaled: 0.0324 (0.0382)  loss_giou_2_unscaled: 0.2466 (0.2867)  cardinality_error_2_unscaled: 232.8750 (237.7375)  loss_ce_enc_unscaled: 0.6836 (0.8301)  loss_bbox_enc_unscaled: 0.0497 (0.0545)  loss_giou_enc_unscaled: 0.3381 (0.3507)  cardinality_error_enc_unscaled: 255.6250 (269.9125)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.368
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Early stopping: Current mAP (max(regular, EMA)): 0.3579, Best: 0.4376, Diff: -0.0797, Min delta: 0.001
# Early stopping: No improvement in mAP for 5 epochs (best: 0.4376, current: 0.3579)
# Training time 0:12:27
# Results saved to drive/MyDrive/wheres-wally/results.json
# Test:  [0/2]  eta: 0:00:37  class_error: 18.18  loss: 11.1359 (11.1359)  loss_ce: 0.9648 (0.9648)  loss_bbox: 0.1982 (0.1982)  loss_giou: 0.9347 (0.9347)  loss_ce_0: 0.9414 (0.9414)  loss_bbox_0: 0.2435 (0.2435)  loss_giou_0: 1.0476 (1.0476)  loss_ce_1: 0.8906 (0.8906)  loss_bbox_1: 0.2705 (0.2705)  loss_giou_1: 1.0930 (1.0930)  loss_ce_2: 0.8906 (0.8906)  loss_bbox_2: 0.2727 (0.2727)  loss_giou_2: 1.0936 (1.0936)  loss_ce_enc: 0.9336 (0.9336)  loss_bbox_enc: 0.2873 (0.2873)  loss_giou_enc: 1.0738 (1.0738)  loss_ce_unscaled: 0.9648 (0.9648)  class_error_unscaled: 18.1818 (18.1818)  loss_bbox_unscaled: 0.0396 (0.0396)  loss_giou_unscaled: 0.4674 (0.4674)  cardinality_error_unscaled: 276.1250 (276.1250)  loss_ce_0_unscaled: 0.9414 (0.9414)  loss_bbox_0_unscaled: 0.0487 (0.0487)  loss_giou_0_unscaled: 0.5238 (0.5238)  cardinality_error_0_unscaled: 266.8750 (266.8750)  loss_ce_1_unscaled: 0.8906 (0.8906)  loss_bbox_1_unscaled: 0.0541 (0.0541)  loss_giou_1_unscaled: 0.5465 (0.5465)  cardinality_error_1_unscaled: 256.3750 (256.3750)  loss_ce_2_unscaled: 0.8906 (0.8906)  loss_bbox_2_unscaled: 0.0545 (0.0545)  loss_giou_2_unscaled: 0.5468 (0.5468)  cardinality_error_2_unscaled: 260.2500 (260.2500)  loss_ce_enc_unscaled: 0.9336 (0.9336)  loss_bbox_enc_unscaled: 0.0575 (0.0575)  loss_giou_enc_unscaled: 0.5369 (0.5369)  cardinality_error_enc_unscaled: 286.6250 (286.6250)  time: 18.9607  data: 18.7888  max mem: 8355
# Test:  [1/2]  eta: 0:00:09  class_error: 33.33  loss: 8.5229 (9.8294)  loss_ce: 0.6719 (0.8184)  loss_bbox: 0.1299 (0.1641)  loss_giou: 0.6543 (0.7945)  loss_ce_0: 0.6445 (0.7930)  loss_bbox_0: 0.2435 (0.2846)  loss_giou_0: 0.8631 (0.9553)  loss_ce_1: 0.6211 (0.7559)  loss_bbox_1: 0.1585 (0.2145)  loss_giou_1: 0.7795 (0.9362)  loss_ce_2: 0.5352 (0.7129)  loss_bbox_2: 0.2603 (0.2665)  loss_giou_2: 0.8213 (0.9575)  loss_ce_enc: 0.6719 (0.8027)  loss_bbox_enc: 0.2873 (0.3530)  loss_giou_enc: 0.9671 (1.0204)  loss_ce_unscaled: 0.6719 (0.8184)  class_error_unscaled: 18.1818 (25.7576)  loss_bbox_unscaled: 0.0260 (0.0328)  loss_giou_unscaled: 0.3271 (0.3973)  cardinality_error_unscaled: 276.1250 (276.1458)  loss_ce_0_unscaled: 0.6445 (0.7930)  loss_bbox_0_unscaled: 0.0487 (0.0569)  loss_giou_0_unscaled: 0.4315 (0.4777)  cardinality_error_0_unscaled: 254.8333 (260.8542)  loss_ce_1_unscaled: 0.6211 (0.7559)  loss_bbox_1_unscaled: 0.0317 (0.0429)  loss_giou_1_unscaled: 0.3898 (0.4681)  cardinality_error_1_unscaled: 243.6667 (250.0208)  loss_ce_2_unscaled: 0.5352 (0.7129)  loss_bbox_2_unscaled: 0.0521 (0.0533)  loss_giou_2_unscaled: 0.4107 (0.4787)  cardinality_error_2_unscaled: 235.3333 (247.7917)  loss_ce_enc_unscaled: 0.6719 (0.8027)  loss_bbox_enc_unscaled: 0.0575 (0.0706)  loss_giou_enc_unscaled: 0.4835 (0.5102)  cardinality_error_enc_unscaled: 281.8333 (284.2292)  time: 9.5474  data: 9.3974  max mem: 8355
# Test: Total time: 0:00:19 (9.5832 s / it)
# Averaged stats: class_error: 33.33  loss: 8.5229 (9.8294)  loss_ce: 0.6719 (0.8184)  loss_bbox: 0.1299 (0.1641)  loss_giou: 0.6543 (0.7945)  loss_ce_0: 0.6445 (0.7930)  loss_bbox_0: 0.2435 (0.2846)  loss_giou_0: 0.8631 (0.9553)  loss_ce_1: 0.6211 (0.7559)  loss_bbox_1: 0.1585 (0.2145)  loss_giou_1: 0.7795 (0.9362)  loss_ce_2: 0.5352 (0.7129)  loss_bbox_2: 0.2603 (0.2665)  loss_giou_2: 0.8213 (0.9575)  loss_ce_enc: 0.6719 (0.8027)  loss_bbox_enc: 0.2873 (0.3530)  loss_giou_enc: 0.9671 (1.0204)  loss_ce_unscaled: 0.6719 (0.8184)  class_error_unscaled: 18.1818 (25.7576)  loss_bbox_unscaled: 0.0260 (0.0328)  loss_giou_unscaled: 0.3271 (0.3973)  cardinality_error_unscaled: 276.1250 (276.1458)  loss_ce_0_unscaled: 0.6445 (0.7930)  loss_bbox_0_unscaled: 0.0487 (0.0569)  loss_giou_0_unscaled: 0.4315 (0.4777)  cardinality_error_0_unscaled: 254.8333 (260.8542)  loss_ce_1_unscaled: 0.6211 (0.7559)  loss_bbox_1_unscaled: 0.0317 (0.0429)  loss_giou_1_unscaled: 0.3898 (0.4681)  cardinality_error_1_unscaled: 243.6667 (250.0208)  loss_ce_2_unscaled: 0.5352 (0.7129)  loss_bbox_2_unscaled: 0.0521 (0.0533)  loss_giou_2_unscaled: 0.4107 (0.4787)  cardinality_error_2_unscaled: 235.3333 (247.7917)  loss_ce_enc_unscaled: 0.6719 (0.8027)  loss_bbox_enc_unscaled: 0.0575 (0.0706)  loss_giou_enc_unscaled: 0.4835 (0.5102)  cardinality_error_enc_unscaled: 281.8333 (284.2292)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.336
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.437
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Test results: {'class_error': 25.75757598876953, 'loss': 9.829408168792725, 'loss_ce': 0.818359375, 'loss_bbox': 0.16405068337917328, 'loss_giou': 0.7945086061954498, 'loss_ce_0': 0.79296875, 'loss_bbox_0': 0.28456202149391174, 'loss_giou_0': 0.9553179442882538, 'loss_ce_1': 0.755859375, 'loss_bbox_1': 0.21451429277658463, 'loss_giou_1': 0.9362460076808929, 'loss_ce_2': 0.712890625, 'loss_bbox_2': 0.266485333442688, 'loss_giou_2': 0.9574636816978455, 'loss_ce_enc': 0.802734375, 'loss_bbox_enc': 0.3530058413743973, 'loss_giou_enc': 1.0204412341117859, 'loss_ce_unscaled': 0.818359375, 'class_error_unscaled': 25.75757598876953, 'loss_bbox_unscaled': 0.03281013760715723, 'loss_giou_unscaled': 0.3972543030977249, 'cardinality_error_unscaled': 276.1458435058594, 'loss_ce_0_unscaled': 0.79296875, 'loss_bbox_0_unscaled': 0.05691240541636944, 'loss_giou_0_unscaled': 0.4776589721441269, 'cardinality_error_0_unscaled': 260.8541717529297, 'loss_ce_1_unscaled': 0.755859375, 'loss_bbox_1_unscaled': 0.042902858927845955, 'loss_giou_1_unscaled': 0.46812300384044647, 'cardinality_error_1_unscaled': 250.02083587646484, 'loss_ce_2_unscaled': 0.712890625, 'loss_bbox_2_unscaled': 0.05329706706106663, 'loss_giou_2_unscaled': 0.47873184084892273, 'cardinality_error_2_unscaled': 247.7916717529297, 'loss_ce_enc_unscaled': 0.802734375, 'loss_bbox_enc_unscaled': 0.07060116901993752, 'loss_giou_enc_unscaled': 0.5102206170558929, 'cardinality_error_enc_unscaled': 284.2291717529297, 'results_json': {'class_map': [{'class': 'odwald', 'map@50:95': 0.008899217896066132, 'map@50': 0.03099055886296025, 'precision': 0.0, 'recall': 1.0}, {'class': 'wally', 'map@50:95': 0.46019801980198016, 'map@50': 0.865346534653465, 'precision': 0.6, 'recall': 1.0}, {'class': 'wenda', 'map@50:95': 0.20278017646127589, 'map@50': 0.3383590037942041, 'precision': 0.0, 'recall': 1.0}, {'class': 'wizard_whitebeard', 'map@50:95': 0.6714521452145215, 'map@50': 1.0, 'precision': 1.0, 'recall': 1.0}, {'class': 'all', 'map@50:95': 0.3358323898434609, 'map@50': 0.5586740243276574, 'precision': 0.4, 'recall': 1.0}], 'map': 0.5586740243276574, 'precision': 0.4, 'recall': 1.0}, 'coco_eval_bbox': [0.3358323898434609, 0.5586740243276574, 0.41857927996541855, 0.0006100685588798991, 0.4372295037873832, -1.0, 0.3770833333333333, 0.3770833333333333, 0.4333333333333333, 0.1625, 0.5083333333333334, -1.0]}
# Results saved to drive/MyDrive/wheres-wally/metrics_plot.png

# %%
from PIL import Image

Image.open("/content/output/metrics_plot.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-841848762.py in <cell line: 0>()
#       1 from PIL import Image
#       2
# ----> 3 Image.open("/content/output/metrics_plot.png")
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/output/metrics_plot.png'

# %%
# !ls -la /content/output
# Out:
# total 1959704
# drwxr-xr-x 3 root root      4096 Aug  6 13:34 .
# drwxr-xr-x 1 root root      4096 Aug  6 13:17 ..
# -rw-r--r-- 1 root root 535040506 Aug  6 13:34 checkpoint0009.pth
# -rw-r--r-- 1 root root 401311829 Aug  6 13:34 checkpoint_best_ema.pth
# -rw-r--r-- 1 root root 401320041 Aug  6 13:25 checkpoint_best_regular.pth
# -rw-r--r-- 1 root root 133737350 Aug  6 13:34 checkpoint_best_total.pth
# -rw-r--r-- 1 root root 535030322 Aug  6 13:34 checkpoint.pth
# drwxr-xr-x 2 root root      4096 Aug  6 13:19 eval
# -rw-r--r-- 1 root root      4412 Aug  6 13:34 events.out.tfevents.1754486237.14154fd71cd6.1731.0
# -rw-r--r-- 1 root root     80406 Aug  6 13:34 log.txt
# -rw-r--r-- 1 root root    157277 Aug  6 13:34 metrics_plot.png
# -rw-r--r-- 1 root root      1651 Aug  6 13:34 results.json

# %% [markdown]
# ## Deploy a Trained RF-DETR Model
#
# Deploying to Roboflow allows you to create multi-step computer vision applications that run both in the cloud and your own hardware. Please wait a moment while Roboflow indexes your model.

# %%
model.deploy_to_roboflow(
  workspace="roboflow-jvuqo",
  project_id="basketball-player-detection-2",
  version=13,
  api_key=os.environ["ROBOFLOW_API_KEY"]
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/13
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/model/13

# %% [markdown]
# ## Evaluate Fine-tuned RF-DETR Model

# %% [markdown]
# Before benchmarking the model, we need to load the best saved checkpoint. To ensure it fits on the GPU, we first need to free up GPU memory. This involves deleting any remaining references to previously used objects, triggering Python’s garbage collector, and clearing the CUDA memory cache.

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [Before] Allocated: 146.49 MB | Reserved: 10432.00 MB
# [WARNING] Object not fully garbage collected yet.
# [After]  Allocated: 146.49 MB | Reserved: 316.00 MB

# %% [markdown]
# We load the best-performing model from the `checkpoint_best_total.pth` file using the `RFDETRMedium` class. This checkpoint contains the trained weights from our most successful training run. After loading, we call `optimize_for_inference()`, which prepares the model for efficient inference.

# %%
model = RFDETRMedium(pretrain_weights="/content/output/checkpoint_best_total.pth")
model.optimize_for_inference()

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 169/169 [00:03<00:00, 44.91it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()
print(map_result)
# Out:
# Average Precision (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.568
# Average Precision (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.908
# Average Precision (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.580
# Average Precision (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.321
# Average Precision (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ]                 = 0.758
# Average Precision (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ]                 = 0.809

# %% [markdown]
# ## Run Inference with Fine-tuned RF-DETR Model

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
# !pip install -q inference-gpu==0.51.7

# %%
from inference import get_model

MODEL_ID = "basketball-player-detection-2/13"
model_rf = get_model(model_id=MODEL_ID, api_key = userdata.get("ROBOFLOW_API_KEY"))

# %%
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

result = model_rf.infer(image, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %% [markdown]
# <div align="center">
#   <p>
#     Looking for more tutorials or have questions?
#     Check out our <a href="https://github.com/roboflow/notebooks">GitHub repo</a> for more notebooks,
#     or visit our <a href="https://discord.gg/GbfgXGJ8Bk">discord</a>.
#   </p>
#
#   <p>
#     <strong>If you found this helpful, please consider giving us a ⭐
#     <a href="https://github.com/roboflow/notebooks">on GitHub</a>!</strong>
#   </p>
#
# </div>
